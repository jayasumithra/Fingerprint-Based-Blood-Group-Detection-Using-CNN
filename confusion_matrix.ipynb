# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load trained model
model = load_model("model_blood_group_detection.h5")

# Dataset path
test_path = "dataset/test"   # change if your test dataset path is different

# Image generator
datagen = ImageDataGenerator(rescale=1./255)

test_generator = datagen.flow_from_directory(
    test_path,
    target_size=(256,256),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Get predictions
predictions = model.predict(test_generator)
y_pred = np.argmax(predictions, axis=1)

# True labels
y_true = test_generator.classes

# Generate confusion matrix
cm = tf.math.confusion_matrix(y_true, y_pred)

cm = cm.numpy()

# Class labels
labels = list(test_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(8,6))
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.xticks(range(len(labels)), labels)
plt.yticks(range(len(labels)), labels)

for i in range(len(labels)):
    for j in range(len(labels)):
        plt.text(j, i, cm[i,j], ha="center", va="center")

plt.colorbar()

# Save image
plt.savefig("confusion_matrix.png")

plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 16
#      13 # Image generator
#      14 datagen = ImageDataGenerator(rescale=1./255)
# ---> 16 test_generator = datagen.flow_from_directory(
#      17     test_path,
#      18     target_size=(256,256),
#      19     batch_size=32,
#      20     class_mode='categorical',
#      21     shuffle=False
#      22 )
#      24 # Get predictions
#      25 predictions = model.predict(test_generator)
#
# File D:\fingerprint-based-blood-group-detection-main\tfenv\lib\site-packages\keras\src\legacy\preprocessing\image.py:1136, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1118 def flow_from_directory(
#    1119     self,
#    1120     directory,
#    (...)
#    1134     keep_aspect_ratio=False,
#    1135 ):
# -> 1136     return DirectoryIterator(
#    1137         directory,
#    1138         self,
#    1139         target_size=target_size,
#    1140         color_mode=color_mode,
#    1141         keep_aspect_ratio=keep_aspect_ratio,
#    1142         classes=classes,
#    1143         class_mode=class_mode,
#    1144         data_format=self.data_format,
#    1145         batch_size=batch_size,
#    1146         shuffle=shuffle,
#    1147         seed=seed,
#    1148         save_to_dir=save_to_dir,
#    1149         save_prefix=save_prefix,
#    1150         save_format=save_format,
#    1151         follow_links=follow_links,
#    1152         subset=subset,
#    1153         interpolation=interpolation,
#    1154         dtype=self.dtype,
#    1155     )
#
# File D:\fingerprint-based-blood-group-detection-main\tfenv\lib\site-packages\keras\src\legacy\preprocessing\image.py:456, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     454 if not classes:
#     455     classes = []
# --> 456     for subdir in sorted(os.listdir(directory)):
#     457         if os.path.isdir(os.path.join(directory, subdir)):
#     458             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset/test'
