# %%
import os
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import classification_report

# %%
file_path = r'D:\fingerprint-based-blood-group-detection-main\dataset\dataset_blood_group'

# List all classes in the dataset
name_class = os.listdir(file_path)
print(name_class)
# Out:
# ['A+', 'A-', 'AB+', 'AB-', 'B+', 'B-', 'O+', 'O-']

# %%
# Get file paths for all images in the dataset
filepaths = list(glob.glob(file_path + '/**/*.*'))

# Example of printing a subset of file paths
print(filepaths[-6:-1])

# Extract labels from file paths
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
print(labels)
# Out:
# ['D:\\fingerprint-based-blood-group-detection-main\\dataset\\dataset_blood_group\\O-\\cluster_7_964.BMP', 'D:\\fingerprint-based-blood-group-detection-main\\dataset\\dataset_blood_group\\O-\\cluster_7_977.BMP', 'D:\\fingerprint-based-blood-group-detection-main\\dataset\\dataset_blood_group\\O-\\cluster_7_979.BMP', 'D:\\fingerprint-based-blood-group-detection-main\\dataset\\dataset_blood_group\\O-\\cluster_7_985.BMP', 'D:\\fingerprint-based-blood-group-detection-main\\dataset\\dataset_blood_group\\O-\\cluster_7_998.BMP']
# ['A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A-', 'A- ...

# %%
# Create a DataFrame with file paths and labels
filepath = pd.Series(filepaths, name='Filepath').astype(str)
Labels = pd.Series(labels, name='Label')
data = pd.concat([filepath, Labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
print(data.head(5))

# Visualize class distribution
counts = data.Label.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90)
plt.show()
# Out:
#                                             Filepath Label
# 0  D:\fingerprint-based-blood-group-detection-mai...    O-
# 1  D:\fingerprint-based-blood-group-detection-mai...    A+
# 2  D:\fingerprint-based-blood-group-detection-mai...    B+
# 3  D:\fingerprint-based-blood-group-detection-mai...    B+
# 4  D:\fingerprint-based-blood-group-detection-mai...    B+

# %%
# Split data into training and testing sets
train, test = train_test_split(data, test_size=0.20, random_state=42)

# Visualize some images from the dataset
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(10, 8), subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()

# %%
# Set up ImageDataGenerator for training and validation data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(256, 256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)

valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(256, 256),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
# Out:
# Found 4800 validated image filenames belonging to 8 classes.
# Found 1200 validated image filenames belonging to 8 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the AlexNet model
model = Sequential([
    Conv2D(96, kernel_size=(11, 11), strides=4, activation='relu', input_shape=(227, 227, 3)),
    MaxPooling2D(pool_size=(3, 3), strides=2),
    Conv2D(256, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(3, 3), strides=2),
    Conv2D(384, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(384, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(3, 3), strides=2),
    Flatten(),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(8, activation='softmax')
])

model.compile(
    optimizer="adam",
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Train the model
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=20,
)
# Out:
# Epoch 1/20
# 150/150 [==============================] - 1482s 10s/step - loss: 39.3491 - accuracy: 0.1450 - val_loss: 2.0606 - val_accuracy: 0.1750
# Epoch 2/20
# 150/150 [==============================] - 642s 4s/step - loss: 2.0719 - accuracy: 0.1642 - val_loss: 2.0597 - val_accuracy: 0.1750
# Epoch 3/20
# 150/150 [==============================] - 456s 3s/step - loss: 2.0726 - accuracy: 0.1630 - val_loss: 2.0609 - val_accuracy: 0.1750
# Epoch 4/20
# 150/150 [==============================] - 646s 4s/step - loss: 2.0666 - accuracy: 0.1711 - val_loss: 2.0612 - val_accuracy: 0.1750
# Epoch 5/20
# 150/150 [==============================] - 443s 3s/step - loss: 2.0683 - accuracy: 0.1717 - val_loss: 2.0592 - val_accuracy: 0.1750
# Epoch 6/20
# 150/150 [==============================] - 418s 3s/step - loss: 2.0700 - accuracy: 0.1670 - val_loss: 2.0595 - val_accuracy: 0.1750
# Epoch 7/20
# 150/150 [==============================] - 383s 3s/step - loss: 2.0712 - accuracy: 0.1636 - val_loss: 2.0582 - val_accuracy: 0.1750
# Epoch 8/20
# 150/150 [==============================] - 348s 2s/step - loss: 2.0678 - accuracy: 0.1680 - val_loss: 2.0595 - val_accuracy: 0.1750
# Epoch 9/20
# 150/150 [==============================] - 341s 2s/step - loss: 2.0644 - accuracy: 0.1759 - val_loss: 2.0604 - val_accuracy: 0.1750
# Epoch 10/20
# 150/150 [==============================] - 336s 2s/step - loss: 2.0696 - accuracy: 0.1662 - val_loss: 2.0596 - val_accuracy: 0.1750
# Epoch 11/20
# 150/150 [==============================] - 359s 2s/step - loss: 2.0674 - accuracy: 0.1685 - val_loss: 2.0589 - val_accuracy: 0.1750
# Epoch 12/20
# 150/150 [==============================] - 338s 2s/step - loss: 2.0695 - accuracy: 0.1611 - val_loss: 2.0597 - val_accuracy: 0.1750
# Epoch 13/20
# 150/150 [==============================] - 986s 7s/step - loss: 2.0687 - accuracy: 0.1575 - val_loss: 2.0599 - val_accuracy: 0.1750
# Epoch 14/20
# 150/150 [==============================] - 1566s 10s/step - loss: 2.0702 - accuracy: 0.1608 - val_loss: 2.0604 - val_accuracy: 0.1750
# Epoch 15/20
# 150/150 [==============================] - 1470s 10s/step - loss: 2.0676 - accuracy: 0.1678 - val_loss: 2.0595 - val_accuracy: 0.1750
# Epoch 16/20
# 150/150 [==============================] - 1464s 10s/step - loss: 2.0695 - accuracy: 0.1679 - val_loss: 2.0594 - val_accuracy: 0.1750
# Epoch 17/20
# 150/150 [==============================] - 1588s 11s/step - loss: 2.0675 - accuracy: 0.1707 - val_loss: 2.0596 - val_accuracy: 0.1750
# Epoch 18/20
# 150/150 [==============================] - 579s 4s/step - loss: 2.0700 - accuracy: 0.1641 - val_loss: 2.0603 - val_accuracy: 0.1750
# Epoch 19/20
# 150/150 [==============================] - 571s 4s/step - loss: 2.0702 - accuracy: 0.1626 - val_loss: 2.0592 - val_accuracy: 0.1750
# Epoch 20/20
# 150/150 [==============================] - 510s 3s/step - loss: 2.0675 - accuracy: 0.1693 - val_loss: 2.0599 - val_accuracy: 0.1750

# %%
# Plot training history: accuracy
pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

# Plot training history: loss
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.title("Loss")
plt.show()

# Evaluate the model on test data
results = model.evaluate(valid_gen, verbose=0)
print(f"Test Loss: {results[0]:.5f}")
print(f"Test Accuracy: {results[1]*100:.2f}%")

# Predict labels for test data
pred = model.predict(valid_gen)
pred = np.argmax(pred, axis=1)

# Map predicted labels
labels = train_gen.class_indices
labels = dict((v, k) for k, v in labels.items())
pred = [labels[k] for k in pred]

# Compare predicted labels with true labels and print classification report
y_test = list(test.Label)
print(classification_report(y_test, pred))
# Out:
# Test Loss: 2.05988
# Test Accuracy: 17.50%
#               precision    recall  f1-score   support
#
#           A+       0.00      0.00      0.00        90
#           A-       0.17      1.00      0.30       210
#          AB+       0.00      0.00      0.00       140
#          AB-       0.00      0.00      0.00       158
#           B+       0.00      0.00      0.00       140
#           B-       0.00      0.00      0.00       141
#           O+       0.00      0.00      0.00       182
#           O-       0.00      0.00      0.00       139
#
#     accuracy                           0.17      1200
#    macro avg       0.02      0.12      0.04      1200
# weighted avg       0.03      0.17      0.05      1200
# D:\fingerprint-based-blood-group-detection-main\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\fingerprint-based-blood-group-detection-main\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\fingerprint-based-blood-group-detection-main\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model.save("model_blood_group_detection_alextnet.keras")

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os

# 1️⃣ Load the model
model_path = "model_blood_group_detection_alextnet.keras"
model = load_model(model_path)
print("Model loaded successfully!")

# 2️⃣ Labels
labels = {'A+': 0, 'A-': 1, 'AB+': 2, 'AB-': 3,
          'B+': 4, 'B-': 5, 'O+': 6, 'O-': 7}

labels = {v: k for k, v in labels.items()}

# 3️⃣ Test Image Path (update this image name)
img_path = r"D:\fingerprint-based-blood-group-detection-main\dataset\dataset_blood_group\A+\cluster_0_1005.BMP"

if not os.path.exists(img_path):
    raise FileNotFoundError("Image not found: " + img_path)

# 4️⃣ Load & Preprocess Image (AlexNet uses 227x227)
img = image.load_img(img_path, target_size=(227, 227))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x / 255.0

# 5️⃣ Predict
result = model.predict(x)
predicted_class = np.argmax(result)
predicted_label = labels[predicted_class]
confidence = result[0][predicted_class] * 100

# 6️⃣ Show Output
plt.imshow(img)
plt.axis("off")
plt.title(f"Prediction: {predicted_label} ({confidence:.2f}%)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 9
#       7 # 1️⃣ Load the model (already in the same folder as notebook)
#       8 model_path = 'model_blood_group_detection_alexnet.keras'
# ----> 9 model = load_model(model_path)
#      10 print("Model loaded successfully!")
#      12 # 2️⃣ Labels
#
# File D:\fingerprint-based-blood-group-detection-main\venv\lib\site-packages\tensorflow\python\keras\saving\save.py:211, in load_model(filepath, custom_objects, compile, options)
#     209     filepath = path_to_string(filepath)
#     210     if isinstance(filepath, six.string_types):
# --> 211       loader_impl.parse_saved_model(filepath)
#     212       return saved_model_load.load(filepath, compile, options)
#     214 raise IOError(
#     215     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     216     'available) or SavedModel.')
#
# File D:\fingerprint-based-blood-group-detection-main\venv\lib\site-packages\tensorflow\python\saved_model\loader_impl.py:111, in parse_saved_model(export_dir)
#     109     raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     110 else:
# --> 111   raise IOError("SavedModel file does not exist at: %s/{%s|%s}" %
#     112                 (export_dir,
#     113                  constants.SAVED_MODEL_FILENAME_PBTXT,
#     114                  constants.SAVED_MODEL_FILENAME_PB))
#
# OSError: SavedModel file does not exist at: model_blood_group_detection_alexnet.keras/{saved_model.pbtxt|saved_model.pb}

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Alexnet.ipynb', 'model_blood_group_detection_alextnet.keras']
